# %%
# %pip install -q python-dotenv openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Write about recursion in programming."
        }
    ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='Recursion is a powerful concept in programming where a function calls itself in order to solve a problem. This technique allows for elegant and compact solutions to certain types of problems, such as problems that can be broken down into smaller, similar subproblems.\n\nRecursion consists of two main parts: the base case and the recursive case. The base case is the stopping condition for the recursion, preventing it from infinitely calling itself. Once the base case is reached, the recursion "unwinds" and the function calls begin to return values back up the chain. The recursive case is where the function calls itself with smaller or simpler inputs in order to make progress towards the base case.\n\nOne classic example of recursion is the factorial function, where the factorial of a non-negative integer n is the product of all positive integers less than or equal to n. The factorial function can be defined recursively as follows:\n\n```python\ndef factorial(n):\n    if n == 0:\n        return 1\n    else:\n        return n * factorial(n - 1)\n```\n\nRecursion can be a powerful tool, but it is important to use it judiciously as it can lead to performance issues if not used carefully. Understanding how recursion works and being able to identify when it is an appropriate approach can help you leverage this powerful technique in your programming endeavors.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)
